# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# HERTZSPRUNG-RUSSELL DIAGRAM

# %% [markdown]
# One of the most useful and powerful plots in astrophysics is the Hertzsprung-Russell diagram (hereafter called the H-R diagram). It originated in 1911 when the Danish astronomer, Ejnar Hertzsprung, plotted the absolute magnitude of stars against their colour (hence effective temperature). Independently in 1913 the American astronomer Henry Norris Russell used spectral class against absolute magnitude. Their resultant plots showed that the relationship between temperature and luminosity of a star was not random but instead appeared to fall into distinct groups. These are seen in the H-R diagram below. It has a few specific stars included in the plot but otherwise just shows the main regions.

# %% [markdown]
# ![HRDiagram%20%281%29.png](attachment:HRDiagram%20%281%29.png)
#
#
# The most common stars are those on the main sequence, the region where stars spend the majority
# of their lives. Main sequence stars burn hydrogen into helium, via nuclear fusion, in their cores. The
# position of a star on the main sequence depends on its mass. The lower mass stars (from the mass of
# the Sun down to about 0.08 solar masses) are cooler and dimmer, and occupy the lower right of the
# main sequence. The higher mass stars (from about 2 to 50 solar masses) are hotter and brighter, and
# occupy the upper left of the main sequence

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# COLOR-MAGNITUDE DIAGRAM

# %% [markdown]
# ---What does a Colour magnitude diagram show?
#
# colour–magnitude diagram, in astronomy, graph showing the relation between the absolute magnitudes (brightnesses) of stars and their colours, which are closely related to their temperatures and spectral types.

# %% [markdown]
# ---What is the difference between color magnitude diagram and H-R diagram?
#
# A color magnitude diagram is a variant of the Hertzsprung-Russell diagram. While the Hertzsprung-Russell (H-R) diagram is a summary of temperatures and magnitudes of individual stars, a color magnitude diagram (CMD) is dedicated to the study of star clusters. The two most common star clusters are globular and open.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# HR-DIAGRAM FOR OPEN AND GLOBULAR CLUSTERS

# %% [markdown]
# ![HR-M13-M5-M3-M46-M37-M67.jpg](attachment:HR-M13-M5-M3-M46-M37-M67.jpg)
#
# (1)OPEN CLUSTERS HAVE MORE NUMBER OF BLUE AND HOT STARS WITH FEW RED GIANTS
#
# (2)GLOBULAR, OLD CLUSTERS HAVE VERY FEW BLUE STARS AS MOST OF THESE HAVE LEFT THE MAIN SEQUENCE, AND MORE YELLOW STARS IN THE MIDDLE

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# DISTANCE MODULUS:
#
# The expression m - M is called the distance modulus and is a measure of distance to the object. An object with a distance modulus of 0 is exactly 10 parsecs away. If the distance modulus is negative, the object is closer than 10 parsecs, and its apparent magnitude is brighter than its absolute magnitude.
#
# ![10.04.2023_14.57.17_REC.png](attachment:10.04.2023_14.57.17_REC.png)
#
# (image taken from https://astronomy.swin.edu.au/cosmos/d/Distance+Modulus)

# %% [markdown]
# -------------------------------------------------------------------------------

# %% [markdown]
# ISOCHRONES:
#
#
# Isochrone is a line on a diagram or map connecting points relating to the same time or equal times.
# Astronomers use the length of the main sequence to estimate the age of a cluster. By comparing the HRD observed to a computer model called an isochrone, it is possible to precisely determine the age of a star cluster.
#
# In stellar evolution, an isochrone is a curve on the Hertzsprung-Russell diagram, representing a population of stars of the same age but with different mass.
#
# ![Isochrones_of_several_ages.png](attachment:Isochrones_of_several_ages.png)
#
#
# Cluster age is measured by fitting isochrones to the cluster magnitude diagram. Age is determined from the turn-off point–where cluster members leave the main sequence and become red giants. Isochrones are theoretical models relating turn-off point to age based on state of the art understanding of stellar evolution

# %% [markdown]
# generating a graph of isochrones for clusters with METALLICITY=0.008

# %%
loga,logl,logte = np.loadtxt('https://raw.githubusercontent.com/HorizonIITM/PythonForAstronomy/master/Color-Magnitude-Diagrams/isoc_z008.dat',usecols=(0,3,4),unpack =True)
# age----luminousity---temperature
w7 = np.where(loga == 7.0)
w7_5 = np.where(loga == 7.5)
w8 = np.where(loga == 8.0)
w8_5 = np.where(loga == 8.5)
w9 = np.where(loga == 9.0)
plt.figure(figsize=[8,5])
    
plt.plot(logte[w7], logl[w7],label='10 Myr')
plt.plot(logte[w8], logl[w8],label='100 Myr')
plt.plot(logte[w7_5], logl[w7_5],label='31.6 Myr')
plt.plot(logte[w8_5], logl[w8_5],label='316.2Myr')
plt.plot(logte[w9], logl[w9],label='1 Byr')

plt.xlabel('Log(Teff)')
plt.ylabel('Log L')
plt.axis([5.0,3.5,0,6])
plt.title("Isochrones for star cluster with metallicity z =0.008")
plt.legend()
plt.savefig("cmdconstmetallicity.pdf")

# %% [markdown]
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ------------------------------

# %%
Mb1,Mv1 =  np.loadtxt('https://raw.githubusercontent.com/HorizonIITM/PythonForAstronomy/master/Color-Magnitude-Diagrams/isoc_z008.dat',usecols=(8,9),unpack=True)
Mb2,Mv2 =  np.loadtxt('https://raw.githubusercontent.com/HorizonIITM/PythonForAstronomy/master/Color-Magnitude-Diagrams/isoc_z0001.dat',usecols=(8,9),unpack=True)
Mb3,Mv3 =  np.loadtxt('https://raw.githubusercontent.com/HorizonIITM/PythonForAstronomy/master/Color-Magnitude-Diagrams/isoc_z0004.dat',usecols=(8,9),unpack=True)
Mb4,Mv4 =  np.loadtxt('https://raw.githubusercontent.com/HorizonIITM/PythonForAstronomy/master/Color-Magnitude-Diagrams/isoc_z004.dat',usecols=(8,9),unpack=True)
Mb5,Mv5 =  np.loadtxt('https://raw.githubusercontent.com/HorizonIITM/PythonForAstronomy/master/Color-Magnitude-Diagrams/isoc_z019.dat',usecols=(8,9),unpack=True)
Mb6,Mv6 =  np.loadtxt('https://raw.githubusercontent.com/HorizonIITM/PythonForAstronomy/master/Color-Magnitude-Diagrams/isoc_z030.dat',usecols=(8,9),unpack=True)


loga1 =  np.loadtxt('https://raw.githubusercontent.com/HorizonIITM/PythonForAstronomy/master/Color-Magnitude-Diagrams/isoc_z008.dat',usecols=(0),unpack=True)
loga2 =  np.loadtxt('https://raw.githubusercontent.com/HorizonIITM/PythonForAstronomy/master/Color-Magnitude-Diagrams/isoc_z0001.dat',usecols=(0),unpack=True)
loga3 =  np.loadtxt('https://raw.githubusercontent.com/HorizonIITM/PythonForAstronomy/master/Color-Magnitude-Diagrams/isoc_z0004.dat',usecols=(0),unpack=True)
loga4 =  np.loadtxt('https://raw.githubusercontent.com/HorizonIITM/PythonForAstronomy/master/Color-Magnitude-Diagrams/isoc_z004.dat',usecols=(0),unpack=True)
loga5 =  np.loadtxt('https://raw.githubusercontent.com/HorizonIITM/PythonForAstronomy/master/Color-Magnitude-Diagrams/isoc_z019.dat',usecols=(0),unpack=True)
loga6 =  np.loadtxt('https://raw.githubusercontent.com/HorizonIITM/PythonForAstronomy/master/Color-Magnitude-Diagrams/isoc_z030.dat',usecols=(0),unpack=True)


w71 = np.where(loga1 == 8.0)
w72 = np.where(loga2 == 8.0)
w73 = np.where(loga3 == 8.0)
w74 = np.where(loga4 == 8.0)
w75 = np.where(loga5 == 8.0)
w76 = np.where(loga6 == 8.0)
plt.figure(figsize=[8,5])

plt.scatter(Mb1[w71]-Mv1[w71],Mv1[w71],label='z=0.008',s=1.8)
plt.scatter(Mb2[w72]-Mv2[w72],Mv2[w72],label='z=0.0001',s=1.8)
plt.scatter(Mb3[w73]-Mv3[w73],Mv3[w73],label='z=0.004',s=1.8)
plt.scatter(Mb4[w74]-Mv4[w74],Mv4[w74],label='z=0.04',s=1.8)
plt.scatter(Mb5[w75]-Mv5[w75],Mv5[w75],label='z=0.019',s=1.8)
plt.scatter(Mb6[w76]-Mv6[w76],Mv6[w76],label='z=0.030',s=1.8)
plt.title("Isochrones for star cluster with age 100 Myr")
plt.xlabel('B-V')
plt.ylabel('V')
plt.legend()
plt.savefig("cmdconstage.pdf")

# %%
w71 = np.where(loga1 == 10.0)
w72 = np.where(loga2 == 10.0)
w73 = np.where(loga3 == 10.0)
w74 = np.where(loga4 == 10.0)
w75 = np.where(loga5 == 10.0)
w76 = np.where(loga6 == 10.0)

M45v,M45bv = np.loadtxt("https://raw.githubusercontent.com/HorizonIITM/PythonForAstronomy/master/Color-Magnitude-Diagrams/m45.dat",usecols=(2,3),unpack=True)
plt.figure(figsize=[8,5])

plt.scatter(Mb1[w71]-Mv1[w71],Mv1[w71],label='z=0.008',s=1.8)
plt.scatter(Mb2[w72]-Mv2[w72],Mv2[w72],label='z=0.0001',s=1.8)
plt.scatter(Mb3[w73]-Mv3[w73],Mv3[w73],label='z=0.004',s=1.8)
plt.scatter(Mb4[w74]-Mv4[w74],Mv4[w74],label='z=0.04',s=1.8)
plt.scatter(Mb5[w75]-Mv5[w75],Mv5[w75],label='z=0.019',s=1.8)
plt.scatter(Mb6[w76]-Mv6[w76],Mv6[w76],label='z=0.030',s=1.8)
plt.scatter(M45bv,M45v,s=1.2)
plt.title("Isochrones for star cluster with age 100 Myr")

plt.legend()

# %%
plt.figure(figsize=[8,5])

plt.plot(Mb3[w73]-Mv3[w73],Mv3[w73],label='z=0.004')
plt.plot(Mb4[w74]-Mv4[w74],Mv4[w74],label='z=0.04')
plt.plot(Mb6[w76]-Mv6[w76],Mv6[w76],label='z=0.030')
plt.scatter(M45bv,M45v,s=1.2)
plt.title("Isochrones for star cluster with age 100 Myr")
plt.legend()

# %%
w71 = np.where(loga1 == 8.2)
w72 = np.where(loga2 == 8.2)
w73 = np.where(loga3 == 8.2)
w74 = np.where(loga4 == 8.2)
w75 = np.where(loga5 == 8.2)
w76 = np.where(loga6 == 8.2)
plt.figure(figsize=[8,5])

plt.plot(Mb3[w73]-Mv3[w73],Mv3[w73],label='z=0.004')
plt.plot(Mb4[w74]-Mv4[w74],Mv4[w74],label='z=0.04')
plt.plot(Mb6[w76]-Mv6[w76],Mv6[w76],label='z=0.030')
plt.scatter(M45bv,M45v,s=1.2)
plt.title("Isochrones for star cluster with age 100 Myr")
plt.legend()

# %%
plt.figure(figsize=[8,5])

plt.plot(Mb3[w73]-Mv3[w73],Mv3[w73],label='z=0.004')
plt.plot(Mb4[w74]-Mv4[w74],Mv4[w74],label='z=0.04')
plt.plot(Mb6[w76]-Mv6[w76],Mv6[w76],label='z=0.030')
plt.scatter(M45bv,M45v-5.2,s=1.2,label="pleiades data")
plt.title("Isochrones for star cluster with age 100 Myr")
plt.legend()

# %% [markdown]
# Observations:
#
#
# Metallicity should be around 0.03<=[Fe/H]<=0.04
#
#
# Distance Modulus = 5.6
#
#
# log10[age] = 8.2

# %%
plt.figure(figsize=[8,5])

plt.plot(Mb4[w74]-Mv4[w74],Mv4[w74],'k--',label='z=0.04')
plt.plot(Mb6[w76]-Mv6[w76],Mv6[w76],'r--',label='z=0.03')
plt.scatter(M45bv,M45v-5.6,s=1.2,label="pleiades data")
plt.title("Isochrone Fitting for M45")
plt.xlabel('B-V')
plt.ylabel('V')
plt.legend()
plt.savefig("Isochronefitting.pdf")

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# DISTANCE 'm':

# %%
m=10*(10**(5.6/5))
print(f"{m} parsecs")
# Out:
# 131.82567385564067 parsecs

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Age:

# %%
age= 10**(8.2)/10**6
print(f"{age} Myrs")
# Out:
# 158.4893192461111
